# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data Preprocessing
train_datagen = ImageDataGenerator(
    horizontal_flip=True,
    rescale=1./255,
    validation_split = 0.15,
    rotation_range=20,          # 随机旋转范围
    width_shift_range=0.1,      # 随机水平平移范围
    height_shift_range=0.1,     # 随机垂直平移范围
    shear_range=0.2,            # 剪切强度
    zoom_range=0.2,             # 缩放范围
    fill_mode='nearest'         # 填充模式
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_set = "car-classification-data/train"
# Out:
# 2024-04-08 19:31:14.874013: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
batch_size = 16
               
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size=(224,224),
    batch_size=batch_size,
    class_mode='categorical',
    classes = ['MPV','SUV','sedan','hatchback','minibus','pickup','sports'],
    shuffle = True,
    seed=13,
    subset="training",
)

valid_generator = train_datagen.flow_from_directory(
    train_set,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    classes = ['MPV','SUV','sedan','hatchback','minibus','pickup','sports'],
    shuffle = False,
    seed=13,
    subset="validation",
)
# Out:
# Found 29896 images belonging to 7 classes.
# Found 5272 images belonging to 7 classes.

# %%
classes = train_generator.class_indices
classes_index = dict((v,k) for k,v in classes.items())
img = train_generator.filepaths

# Get a batch from the generator
x_batch, y_batch = next(train_generator)
print(classes_index)
print(x_batch.shape)
print(y_batch.shape)
# Out:
# {0: 'MPV', 1: 'SUV', 2: 'sedan', 3: 'hatchback', 4: 'minibus', 5: 'pickup', 6: 'sports'}
# (16, 224, 224, 3)
# (16, 7)

# %%
from PIL import Image

Image_path = img[0]
Image = Image.open(Image_path)
width,height = Image.size
channels = len(Image.getbands())
print(width,height,channels)
# Out:
# 800 567 3

# %%
import matplotlib.pyplot as plt
from keras.preprocessing import image
import os
import random
from keras.preprocessing.image import img_to_array, load_img

selected_images = []

for class_name in classes_index.values():
    class_path = os.path.join(train_set, str(class_name))
    random_image = random.choice(os.listdir(class_path))
    selected_images.append(os.path.join(class_path, random_image))

rows, cols = 2, len(classes)
fig, axs = plt.subplots(rows, cols, figsize=(10, 6))

for i, img_path in enumerate(selected_images, 1):
    class_name = os.path.basename(os.path.dirname(img_path))
    matching_keys = [str(key) for key in classes_index.keys() if str(key).lower() == str(class_name).lower()]
    
    # Load and preprocess the original image
    img_original = load_img(img_path)
    img_array_original = img_to_array(img_original)
    
    img_preprocessed = train_datagen.random_transform(img_array_original)
    
    plt.subplot(rows, cols, i)
    plt.imshow(image.array_to_img(img_array_original))
    plt.title(f"Original: \n {class_name}")
    plt.axis('off')
    
    plt.subplot(rows, cols, i + cols)
    plt.imshow(image.array_to_img(img_preprocessed))
    plt.title(f"Process: \n {class_name}")
    plt.axis('off')

fig.suptitle('[Original and Preprocessed images]')
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras import layers, models

class ChannelAttention(layers.Layer):
    def __init__(self, channel, reduction=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = layers.GlobalAveragePooling2D()
        self.max_pool = layers.GlobalMaxPooling2D()
        self.fc = self.build_fc(channel,reduction)
        self.softmax = layers.Activation('softmax')
        
    def build_fc(self, channel, reduction):
        input_tensor = layers.Input(shape=(channel,))
        x = layers.Dense(channel // reduction, use_bias=False)(input_tensor)
        x = layers.ReLU()(x)
        x = layers.Dense(channel, use_bias=False)(x)
        return models.Model(inputs=input_tensor, outputs=x)

    def call(self, x):
        y1 = self.avg_pool(x)
        y1 = tf.expand_dims(tf.expand_dims(self.fc(y1), 1), 1)

        y2 = self.max_pool(x)
        y2 = tf.expand_dims(tf.expand_dims(self.fc(y2), 1), 1)

        y = self.softmax(y1 + y2)
        return x + x * y

class SpatialAttention(layers.Layer):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()
        assert kernel_size % 2 == 1, "kernel_size = {}".format(kernel_size)
        padding = (kernel_size - 1) // 2
        self.conv = layers.Conv2D(1, kernel_size=kernel_size, padding='same', activation='softmax')

    def call(self, x):
        mask = self.conv(x)
        return x + x * mask

# %%
from keras import backend as K

def accuracy(y_true, y_pred):
    y_true = K.argmax(y_true, axis=-1)
    y_pred = K.argmax(y_pred, axis=-1)
    correct_predictions = K.equal(y_true, y_pred)
    return K.mean(K.cast(correct_predictions, K.floatx()))

def weighted_categorical_crossentropy(y_true, y_pred, weights):
    # Convert weights to tensor
    weights_tensor = tf.convert_to_tensor(weights, dtype=tf.float32)
    # Apply weights to the cross-entropy loss
    weighted_losses = tf.nn.weighted_cross_entropy_with_logits(labels=y_true, logits=y_pred, pos_weight=weights_tensor)
    # Take the mean over all examples
    loss = tf.reduce_mean(weighted_losses)
    return loss

# %%
def WaveletTransformAxisY(batch_img):
    odd_img = batch_img[:, 0::2]
    even_img = batch_img[:, 1::2]
    L = (odd_img + even_img) / 2.0
    H = K.abs(odd_img - even_img)
    return L, H


def WaveletTransformAxisX(batch_img):
    # transpose + fliplr
    tmp_batch = K.permute_dimensions(batch_img, [0, 2, 1])[:, :, ::-1]
    _dst_L, _dst_H = WaveletTransformAxisY(tmp_batch)
    # transpose + flipud
    dst_L = K.permute_dimensions(_dst_L, [0, 2, 1])[:, ::-1, ...]
    dst_H = K.permute_dimensions(_dst_H, [0, 2, 1])[:, ::-1, ...]
    return dst_L, dst_H


def wavelet_transform(img):
    wavelet_L, wavelet_H = WaveletTransformAxisY(img)
    wavelet_LL, wavelet_LH = WaveletTransformAxisX(wavelet_L)
    wavelet_HL, wavelet_HH = WaveletTransformAxisX(wavelet_H)
    return wavelet_LL, wavelet_LH, wavelet_HL, wavelet_HH


def Wavelet(batch_image, n=4):
    # make channel first image
    batch_image = K.permute_dimensions(batch_image, [0, 3, 1, 2])
    r = batch_image[:, 0]
    g = batch_image[:, 1]
    b = batch_image[:, 2]

    wavelet_levels = []
    for i in range(n):  # 4 levels of decomposition
        r_wavelets = wavelet_transform(r)
        g_wavelets = wavelet_transform(g)
        b_wavelets = wavelet_transform(b)

        wavelet_data = list(r_wavelets) + list(g_wavelets) + list(b_wavelets)
        wavelet_level = K.stack(wavelet_data, axis=1)
        wavelet_levels.append(K.permute_dimensions(wavelet_level, [0, 2, 3, 1]))

        r, g, b = r_wavelets[0], g_wavelets[0], b_wavelets[0]  # LL for next level

    return wavelet_levels

def Wavelet_out_shape(input_shapes):
    return [tuple([None, 112, 112, 12]), tuple([None, 56, 56, 12]), 
            tuple([None, 28, 28, 12]), tuple([None, 14, 14, 12])]

# %%
from tensorflow.keras.layers import ReLU, Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Flatten, Dense, Dropout, Reshape, concatenate
from keras.layers import Lambda
from keras.initializers import he_normal
from keras import regularizers
from tensorflow.keras.models import Model

def build_block(input_tensor, filters):
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size=(3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)

    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding='same')(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x


def build_branch_new(input_tensor, filters, reduction=4):
    x = layers.Conv2D(filters[0], kernel_size=(3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    # x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    x = build_block(x, filters[1])
    x = build_block(x, filters[2])
    # x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    x = ChannelAttention(filters[2], reduction=reduction)(x)

    return x


def DWAN(num_classes, reduction=4, spatial_kernel_size=3):
    input_shape = (224, 224, 3)
    input_ = layers.Input(input_shape, name='input')
    wavelet = layers.Lambda(Wavelet, Wavelet_out_shape, name='wavelet')
    input_l1, input_l2, input_l3, input_l4 = wavelet(input_)

    branch1 = build_branch_new(input_l1, [32, 64, 64], reduction=reduction)
    branch2 = build_branch_new(input_l2, [64, 128, 128], reduction=reduction)
    branch3 = build_branch_new(input_l3, [128, 256, 256], reduction=reduction)
    branch4 = build_branch_new(input_l4, [128, 256, 256], reduction=reduction)

    conv_a = layers.Conv2D(64, kernel_size=(3, 3), strides=(2, 2), activation='relu', padding='same', name='conv_1',
                           kernel_initializer=he_normal())(branch1)
    norm_a = layers.BatchNormalization()(conv_a)
    concat_branches1_2 = layers.concatenate([norm_a, branch2])

    conv_b = layers.Conv2D(128, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_1_2', activation='relu',
                           kernel_initializer=he_normal())(concat_branches1_2)
    norm_b = layers.BatchNormalization()(conv_b)
    concat_branches1_2_3 = layers.concatenate([norm_b, branch3])

    conv_c = layers.Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_1_2_3', activation='relu',
                           kernel_initializer=he_normal())(concat_branches1_2_3)
    norm_c = layers.BatchNormalization()(conv_c)
    concat_branches1_2_3_4 = layers.concatenate([norm_c, branch4])

    common_conv = layers.Conv2D(256, kernel_size=3, activation='relu', kernel_initializer=he_normal())(
        concat_branches1_2_3_4)
    common_norm = layers.BatchNormalization()(common_conv)

    spatial = SpatialAttention(kernel_size=spatial_kernel_size)(common_norm)

    global_avg_pooling = layers.GlobalAveragePooling2D()(spatial)

    output = layers.Dense(num_classes, activation='softmax')(global_avg_pooling)

    model = models.Model(inputs=input_, outputs=output)
    return model

DWAN_model = DWAN(num_classes=7)

DWAN_model.summary()
# Out:
# 2024-04-08 19:31:21.569763: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-04-08 19:31:21.656909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.658987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:09.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.74GiB deviceMemoryBandwidth: 1.03TiB/s
# 2024-04-08 19:31:21.659024: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-04-08 19:31:21.662266: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-04-08 19:31:21.662345: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-04-08 19:31:21.663314: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2024-04-08 19:31:21.663642: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2024-04-08 19:31:21.664395: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2024-04-08 19:31:21.665021: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2024-04-08 19:31:21.665218: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-04-08 19:31:21.665323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.679336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.681585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-04-08 19:31:21.682134: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-08 19:31:21.686215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.687045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:09.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.74GiB deviceMemoryBandwidth: 1.03TiB/s
# 2024-04-08 19:31:21.687124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.687935: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:21.688599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-04-08 19:31:21.688646: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-04-08 19:31:22.651687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-04-08 19:31:22.651714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2024-04-08 19:31:22.651726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2024-04-08 19:31:22.651936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:22.653091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:22.654150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-08 19:31:22.655063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30984 MB memory) -> physical GPU (device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:00:09.0, compute capability: 7.0)
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# wavelet (Lambda)                [(None, 112, 112, 12 0           input[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 3488        wavelet[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 64)   6976        wavelet[0][1]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 18496       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 128)  73856       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  13952       wavelet[0][2]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 64) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 2112        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 112, 112, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 112, 112, 64) 0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  8320        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  295168      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 128)  13952       wavelet[0][3]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 64) 0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 128)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  590080      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 256)  33024       activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 256)  295168      activation_18[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 14, 14, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 64) 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 64) 4160        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 256)  0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 256)  590080      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 256)  33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 112, 112, 64) 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  147584      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  16512       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 256)  590080      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 256)  0           batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# channel_attention (ChannelAtten (None, 112, 112, 64) 2048        activation_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 128)  0           batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 256)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 56, 56, 64)   36928       channel_attention[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 256)  65792       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 256)  590080      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 56, 56, 64)   256         conv_1[0][0]
# __________________________________________________________________________________________________
# channel_attention_1 (ChannelAtt (None, 56, 56, 128)  8192        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 256)  1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 192)  0           batch_normalization_28[0][0]
#                                                                  channel_attention_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 256)  0           batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv_1_2 (Conv2D)               (None, 28, 28, 128)  221312      concatenate[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 256)  590080      activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 256)  65792       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv_1_2[0][0]
# __________________________________________________________________________________________________
# channel_attention_2 (ChannelAtt (None, 28, 28, 256)  32768       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 384)  0           batch_normalization_29[0][0]
#                                                                  channel_attention_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 256)  0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv_1_2_3 (Conv2D)             (None, 14, 14, 256)  884992      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 256)  1024        conv_1_2_3[0][0]
# __________________________________________________________________________________________________
# channel_attention_3 (ChannelAtt (None, 14, 14, 256)  32768       activation_22[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 512)  0           batch_normalization_30[0][0]
#                                                                  channel_attention_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# spatial_attention (SpatialAtten (None, 12, 12, 256)  2305        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 256)          0           spatial_attention[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 7)            1799        global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 7,467,944
# Trainable params: 7,457,384
# Non-trainable params: 10,560
# __________________________________________________________________________________________________

# %%
lr=0.0005
class_weights = [0.7, 0.8, 0.8, 0.7, 0.9, 1.7, 0.7]

DWAN_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
    loss=lambda y_true, y_pred: weighted_categorical_crossentropy(y_true,y_pred,class_weights),
    metrics=['accuracy']
)

# Train the model using the data generators
history = DWAN_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=30,
    validation_data=valid_generator,
    validation_steps=len(valid_generator),
)
# Out:
# 2024-04-08 19:31:24.208288: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-04-08 19:31:24.209071: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3000025000 Hz
# Epoch 1/30
# 2024-04-08 19:31:28.722804: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-04-08 19:31:29.225408: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2024-04-08 19:31:29.818909: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-04-08 19:31:30.262083: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 1869/1869 [==============================] - 511s 270ms/step - loss: 0.7234 - accuracy: 0.2720 - val_loss: 0.7202 - val_accuracy: 0.2991
# Epoch 2/30
# 1869/1869 [==============================] - 500s 268ms/step - loss: 0.7134 - accuracy: 0.3546 - val_loss: 0.7224 - val_accuracy: 0.2932
# Epoch 3/30
# 1869/1869 [==============================] - 500s 268ms/step - loss: 0.7056 - accuracy: 0.4196 - val_loss: 0.7133 - val_accuracy: 0.3373
# Epoch 4/30
# 1869/1869 [==============================] - 505s 270ms/step - loss: 0.6996 - accuracy: 0.4691 - val_loss: 0.7049 - val_accuracy: 0.4230
# Epoch 5/30
# 1869/1869 [==============================] - 500s 268ms/step - loss: 0.6954 - accuracy: 0.5029 - val_loss: 0.6954 - val_accuracy: 0.5057
# Epoch 6/30
# 1869/1869 [==============================] - 501s 268ms/step - loss: 0.6911 - accuracy: 0.5375 - val_loss: 0.6994 - val_accuracy: 0.4568
# Epoch 7/30
# 1869/1869 [==============================] - 499s 267ms/step - loss: 0.6876 - accuracy: 0.5644 - val_loss: 0.6977 - val_accuracy: 0.4731
# Epoch 8/30
# 1869/1869 [==============================] - 500s 268ms/step - loss: 0.6858 - accuracy: 0.5768 - val_loss: 0.6882 - val_accuracy: 0.5516
# Epoch 9/30
# 1869/1869 [==============================] - 502s 269ms/step - loss: 0.6832 - accuracy: 0.5981 - val_loss: 0.6856 - val_accuracy: 0.5835
# Epoch 10/30
# 1869/1869 [==============================] - 490s 262ms/step - loss: 0.6817 - accuracy: 0.6095 - val_loss: 0.6822 - val_accuracy: 0.6032
# Epoch 11/30
# 1869/1869 [==============================] - 489s 262ms/step - loss: 0.6797 - accuracy: 0.6262 - val_loss: 0.6814 - val_accuracy: 0.6102
# Epoch 12/30
# 1869/1869 [==============================] - 490s 262ms/step - loss: 0.6783 - accuracy: 0.6338 - val_loss: 0.6813 - val_accuracy: 0.6087
# Epoch 13/30
# 1869/1869 [==============================] - 489s 261ms/step - loss: 0.6767 - accuracy: 0.6472 - val_loss: 0.6802 - val_accuracy: 0.6189
# Epoch 14/30
# 1869/1869 [==============================] - 489s 261ms/step - loss: 0.6752 - accuracy: 0.6601 - val_loss: 0.6797 - val_accuracy: 0.6250
# Epoch 15/30
# 1869/1869 [==============================] - 499s 267ms/step - loss: 0.6743 - accuracy: 0.6652 - val_loss: 0.6751 - val_accuracy: 0.6635
# Epoch 16/30
# 1869/1869 [==============================] - 499s 267ms/step - loss: 0.6724 - accuracy: 0.6824 - val_loss: 0.6772 - val_accuracy: 0.6383
# Epoch 17/30
# 1869/1869 [==============================] - 497s 266ms/step - loss: 0.6722 - accuracy: 0.6819 - val_loss: 0.6787 - val_accuracy: 0.6241
# Epoch 18/30
# 1869/1869 [==============================] - 499s 267ms/step - loss: 0.6704 - accuracy: 0.6963 - val_loss: 0.6781 - val_accuracy: 0.6258
# Epoch 19/30
# 1869/1869 [==============================] - 497s 266ms/step - loss: 0.6698 - accuracy: 0.7017 - val_loss: 0.6723 - val_accuracy: 0.6779
# Epoch 20/30
# 1869/1869 [==============================] - 498s 267ms/step - loss: 0.6689 - accuracy: 0.7078 - val_loss: 0.6717 - val_accuracy: 0.6806
# Epoch 21/30
# 1869/1869 [==============================] - 500s 268ms/step - loss: 0.6676 - accuracy: 0.7183 - val_loss: 0.6720 - val_accuracy: 0.6851
# Epoch 22/30
# 1869/1869 [==============================] - 509s 272ms/step - loss: 0.6673 - accuracy: 0.7194 - val_loss: 0.6719 - val_accuracy: 0.6840
# Epoch 23/30
# 1869/1869 [==============================] - 509s 272ms/step - loss: 0.6661 - accuracy: 0.7294 - val_loss: 0.6741 - val_accuracy: 0.6624
# Epoch 24/30
# 1869/1869 [==============================] - 512s 274ms/step - loss: 0.6655 - accuracy: 0.7346 - val_loss: 0.6687 - val_accuracy: 0.7043
# Epoch 25/30
# 1869/1869 [==============================] - 504s 270ms/step - loss: 0.6651 - accuracy: 0.7357 - val_loss: 0.6668 - val_accuracy: 0.7214
# Epoch 26/30
# 1869/1869 [==============================] - 510s 273ms/step - loss: 0.6640 - accuracy: 0.7447 - val_loss: 0.6677 - val_accuracy: 0.7111
# Epoch 27/30
# 1869/1869 [==============================] - 511s 273ms/step - loss: 0.6635 - accuracy: 0.7497 - val_loss: 0.6672 - val_accuracy: 0.7166
# Epoch 28/30
# 1869/1869 [==============================] - 509s 272ms/step - loss: 0.6629 - accuracy: 0.7539 - val_loss: 0.6696 - val_accuracy: 0.6990
# Epoch 29/30
# 1869/1869 [==============================] - 509s 272ms/step - loss: 0.6624 - accuracy: 0.7572 - val_loss: 0.6655 - val_accuracy: 0.7312
# Epoch 30/30
# 1869/1869 [==============================] - 512s 274ms/step - loss: 0.6617 - accuracy: 0.7631 - val_loss: 0.6655 - val_accuracy: 0.7284
